# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent  # because you are inside Notebooks/
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
    
from util.read_price import (
    read_forecast,
    read_real_prices,

)

# %%
da_lear_det = read_forecast(
    market = "DA",
    model="LEAR",
    kind="deterministic", #probabilistic
)

print(da_lear_det)
# Out:
# C:\Users\mmascare\OneDrive - KU Leuven\Documents\Code\DA_Optimization\Data\DA_CET\DA_LEAR.csv
#                           LEAR
# DateTime
# 2023-01-01 00:00:00 -10.686715
# 2023-01-01 01:00:00 -17.450630
# 2023-01-01 02:00:00 -31.036607
# 2023-01-01 03:00:00 -43.470688
# 2023-01-01 04:00:00 -44.837623
# ...                        ...
# 2023-12-31 19:00:00  52.826862
# 2023-12-31 20:00:00  45.748390
# 2023-12-31 21:00:00  36.308087
# 2023-12-31 22:00:00  37.096057
# 2023-12-31 23:00:00  26.228172
#
# [8760 rows x 1 columns]

# %%
real = read_real_prices(
    market = "IP",
    keep_extra_columns=False
)

print(real)
# Out:
# C:\Users\mmascare\OneDrive - KU Leuven\Documents\Code\DA_Optimization\Data\IP_CET\IP_Real_Prices.csv
# [read_price] Collapsed duplicate timestamps (kept one row via aggregation): 4 timestamp(s). First 4: [Timestamp('2023-10-29 02:00:00'), Timestamp('2023-10-29 02:15:00'), Timestamp('2023-10-29 02:30:00'), Timestamp('2023-10-29 02:45:00')]
# [read_price] Added missing timestamps (will fill by interpolation): 4 timestamp(s). First 4: [Timestamp('2023-03-26 02:00:00'), Timestamp('2023-03-26 02:15:00'), Timestamp('2023-03-26 02:30:00'), Timestamp('2023-03-26 02:45:00')]
#                       Price
# DateTime
# 2023-01-01 00:00:00  -11.28
# 2023-01-01 00:15:00   -4.39
# 2023-01-01 00:30:00   -5.84
# 2023-01-01 00:45:00  -13.46
# 2023-01-01 01:00:00  176.87
# ...                     ...
# 2023-12-31 22:45:00   74.12
# 2023-12-31 23:00:00  243.94
# 2023-12-31 23:15:00  121.17
# 2023-12-31 23:30:00   70.37
# 2023-12-31 23:45:00  -37.26
#
# [35040 rows x 1 columns]

# %%
import pandas as pd

# 1. Read CSV (first column is the datetime index)
df = pd.read_csv(
    "../Data/IP_CET/basic_new.csv",
    index_col=0,
    parse_dates=True
)


# 2. Ensure timezone is UTC
#df.index = df.index.tz_localize("UTC")

# 3. Convert to Europe/Brussels
#df.index = df.index.tz_convert("Europe/Brussels")

# 4. Keep only the first row
df_first = df['pos_ip']

# 5. Make timestamp timezone-naive
df_first.index = df_first.index.tz_localize(None)

# 6. Save
df_first.to_csv("output.csv")
